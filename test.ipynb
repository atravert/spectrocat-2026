# %%
# install spectrochempy

# !pip install -q "spectrochempy @ git+https://github.com/spectrochempy/spectrochempy.git" 

# generate and plot a random dataset
import spectrochempy as spectrochempy

A = scp.random(10,100)
A.plot(title='random data', colorbar=True)
